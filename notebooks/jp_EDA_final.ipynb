# %% [markdown]
# # EDA YOOGLE
#
# En este notebook encontrarás el Análisis exploratorio de datos referente a nuestro proyecto. Para llevar a cabo un análisis de mercado decidimos limitar los Datasets a los Estados de: Nevada, Florida y Virginia.

# %%
#Se conecta Google Colaboratory con Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Se importan las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap

# %%
business_yelp= pd.read_parquet("/content/drive/My Drive/YOOGLE/business_yelp.parquet")
metadata_sitios= pd.read_parquet("/content/drive/My Drive/YOOGLE/metadata_sitios.snappy.parquet")
reviews_google= pd.read_parquet("/content/drive/My Drive/YOOGLE/reviews_google.snappy.parquet")
reviews_yelp= pd.read_parquet("/content/drive/My Drive/YOOGLE/reviews_yelp.snappy.parquet")
tips_yelp= pd.read_parquet("/content/drive/My Drive/YOOGLE/tips_yelp.parquet")
users_yelp= pd.read_parquet("/content/drive/My Drive/YOOGLE/users_yelp.parquet")
users_google= pd.read_parquet("/content/drive/My Drive/YOOGLE/users_google.snappy.parquet")

# %%
#Esta función calcula el porcentaje de valores nulos que tiene cada columna de un determinado dataframe

def porcentaje_nulos(dataframe):

  longitud=dataframe.shape[0]

  #Cantidad de nulos por columna

  nulos_por_columna = dataframe.isnull().sum()

  #Se hace el cálculo del porcentaje
  porcentaje_nulos= nulos_por_columna.apply(lambda x: round(x*100/longitud,2))

  print("porcentaje de valores nulos por columna:\n", porcentaje_nulos)

# %% [markdown]
# # VALORES NULOS
#
# En esta sección analizaremos los valores nulos de cada conjunto de datos, cabe aclarar que estos datasets ya han sido previamente tratados en el ETL y en el EDA preliminar que se encuentra en el repositorio, por lo tanto no es de esperar que los resultados aquí estudiados sean de preocupación.

# %%
porcentaje_nulos(business_yelp)
# Out:
# porcentaje de valores nulos por columna:
#  business_id       0.0
# name              0.0
# address           0.0
# city              0.0
# state             0.0
# postal_code       0.0
# latitude          0.0
# longitude         0.0
# stars             0.0
# num_of_reviews    0.0
# categories        0.0
# dtype: float64

# %%
porcentaje_nulos(metadata_sitios)
# Out:
# porcentaje de valores nulos por columna:
#  address              0.00
# avg_rating           0.00
# category             0.00
# gmap_id              0.00
# latitude             0.00
# longitude            0.00
# name                 0.00
# num_of_reviews       0.00
# relative_results    22.53
# state                0.00
# city                 0.00
# dtype: float64

# %%
porcentaje_nulos(reviews_google)
# Out:
# porcentaje de valores nulos por columna:
#  gmap_id       0.00
# rating        0.00
# text         38.85
# user_id       0.00
# state         0.00
# year          0.00
# month         0.00
# day           0.00
# sentiment     0.00
# dtype: float64

# %%
porcentaje_nulos(reviews_yelp)
# Out:
# porcentaje de valores nulos por columna:
#  review_id      0.0
# business_id    0.0
# user_id        0.0
# rating         0.0
# year           0.0
# month          0.0
# day            0.0
# text           0.0
# sentiment      0.0
# dtype: float64

# %%
porcentaje_nulos(users_google)
# Out:
# porcentaje de valores nulos por columna:
#  user_id    0.0
# name       0.0
# dtype: float64

# %%
porcentaje_nulos(users_yelp)
# Out:
# porcentaje de valores nulos por columna:
#  user_id    0.0
# name       0.0
# dtype: float64

# %%
porcentaje_nulos(tips_yelp)
# Out:
# porcentaje de valores nulos por columna:
#  user_id        0.0
# business_id    0.0
# text           0.0
# year           0.0
# month          0.0
# day            0.0
# dtype: float64

# %% [markdown]
# Como se pudo observar los datos faltan se atribuyen a reseñas sin texto y a negocios que no tienen resultados relacionados. Sin embargo de las reseñas sin texto podemos extraer el rating que califica el lugar y en base a eso se realiza el análisis de sentimientos; con respecto a los resultados relacionados es un plus que nos ayudará a comparar negocios en el sistema de recomendación, pero no es indispensable.

# %% [markdown]
# #OUTLIERS
#
# Vamos a estudiar el intervalo de tiempo en el que transcurren las reseñas para ver si ocurre alguna inconsistencia.

# %%
# Encuentra el valor máximo y mínimo de 'year'
valor_maximo = reviews_google['year'].max()
valor_minimo = reviews_google['year'].min()

print(f'El último año es: {valor_maximo}')
print(f'El primer año es: {valor_minimo}')
# Out:
# El último año es: 2021
# El primer año es: 1990

# %% [markdown]
# Hay reseñas desde 1990 hasta 2021 por parte de Google Maps, esto no puede ocurrir porque Google Maps existe desde 2005. Estos datos desde 1990 hasta 2005 ya se catalogan como resultados inesperados.

# %%
reviews_google[reviews_google["year"]==1990]
# Out:
#                                        gmap_id  rating  \
# 1366481  0x89b64af46a576a43:0x31cd60d2502b5cf5       4
#
#                                                       text  \
# 1366481  Great service. Food is good for a chain, but o...
#
#                        user_id state  year  month  day sentiment
# 1366481  118122900081499203361    VA  1990     12   31         2

# %%
#Transformo reviews_google para tomar todas las reseñas que se hacen desde 2005

reviews_google=reviews_google[reviews_google["year"]>=2005]

# %%
# Encontrar el valor máximo y mínimo de 'year'
valor_maximo = reviews_yelp['year'].max()
valor_minimo = reviews_yelp['year'].min()

print(f'El último año es: {valor_maximo}')
print(f'El primer año es: {valor_minimo}')
# Out:
# El último año es: 2022
# El primer año es: 2005

# %% [markdown]
# Teniendo en cuenta que Yelp existe desde 2004, este dataset si es coherente con la información temporal que presenta.

# %% [markdown]
# Nuestros restaurantes pueden pertenecer a diferentes categorías, las cuales pueden ser muy variadas, hagamos un conteo del total de categorías que se encuentran en los datos.

# %%
# Crea una lista de todas las categorías de business_yelp
categories_yelp = business_yelp['categories'].str.split(',').explode().str.strip().unique()

# Crea una lista de todas las categorías de metadata_sitios
categories_metadata = metadata_sitios['category'].str.split(',').explode().str.strip().unique()

# Une ambas listas y obtiene las categorías únicas
all_categories = pd.Series(list(categories_yelp) + list(categories_metadata)).unique()

print(f"Hay {len(all_categories)} categorías")
# Out:
# Hay 1331 categorías

# %% [markdown]
# Ahora vamos a encontrar las ciudades con mayor número de restaurantes, esto nos permitirá delimitar el análisis de mercado a las principales ciudades y zonas comerciales.

# %%
# Cuenta el número de negocios por ciudad en business_yelp
city_counts_yelp = business_yelp['city'].str.strip().value_counts()

# Cuenta el número de negocios por ciudad en metadata_sitios
city_counts_metadata = metadata_sitios['city'].str.strip().value_counts()

# Suma el número de negocios por ciudad de ambos DataFrames
combined_city_counts = city_counts_yelp.add(city_counts_metadata, fill_value=0)

# Obtiene las 10 ciudades con más negocios y las ordena
top_10_cities = combined_city_counts.sort_values(ascending=False).head(10)

# Imprime el resultado
print("Las 10 ciudades con más restaurantes son:")
print(top_10_cities)
# Out:
# Las 10 ciudades con más restaurantes son:
# Tampa           1339.0
# Philadelphia    1305.0
# Miami           1204.0
# Las Vegas       1187.0
# Orlando          815.0
# Indianapolis     652.0
# Nashville        573.0
# Tucson           566.0
# Jacksonville     535.0
# New Orleans      521.0
# Name: city, dtype: float64

# %% [markdown]
# Aquí nos chocamos con incongruencias en los datos, en el top 2 se encuentra la ciudad de Philadelphia, que como se verá a continuación a veces la ubica en el Estado de Florida y a veces en el Estado de Nevada; sin embargo en la realidad pertenece al Estado de Pensilvania.
#
# Teniendo esto presente decidimos elegir para nuestro análisis de mercado las tres ciudades que si pertenecen a los estados que habiamos predefinido: Tampa, Miami Y Las Vegas. Siendo dos ciudades de Florida y una de Nevada en las que centraremos nuestra atención para iniciar el plan de expansión de nuestro cliente.

# %%
#Imprimo los primeros 5 restaurantes que se encuentran en Philadelphia

business_yelp[business_yelp['city']=='Philadelphia'].head(5)
# Out:
#                business_id                 name                address  \
# 5   ppFCk9aQkM338Rgwpl2F5A                 Wawa       3604 Chestnut St
# 16  n8ecak12IF_jhnPNs37AZA        Baltic Bakery       2609 Edgemont St
# 24  GVqXNt0HKJLpciN9ePxnWw  Crown Fried Chicken        1128 S Broad St
# 46  yFqq66GxRjnhZXPgjA6hnw                  KFC          716 Adams Ave
# 47  kLSEk3qXY1KdtFjxHJ9pww           McDonald's  501 Franklin Mill Cir
#
#             city state postal_code   latitude  longitude  stars  \
# 5   Philadelphia    FL       19104  39.954573 -75.194894    3.0
# 16  Philadelphia    FL       19125  39.976880 -75.116169    4.5
# 24  Philadelphia    FL       19146  39.936891 -75.167284    2.5
# 46  Philadelphia    NV       19124  40.031578 -75.104787    2.0
# 47  Philadelphia    FL       19154  40.088416 -74.965011    1.5
#
#     num_of_reviews                                         categories
# 5               56  Restaurants, Automotive, Delis, Gas Stations, ...
# 16              12                        Food, Bakeries, Restaurants
# 24              16                             Restaurants, Fast Food
# 46               7  Restaurants, Chicken Shop, Fast Food, Chicken ...
# 47              20  Restaurants, Fast Food, Food, Coffee & Tea, Bu...

# %% [markdown]
# También es interesante conocer qué categorías de restaurantes tienen más negocio dentro de los tres Estados.

# %%
# Concatenar las columnas 'categories' de ambos DataFrames
all_categories_series = pd.concat([metadata_sitios['category'], business_yelp['categories']], ignore_index=True)

# Dividir las listas de categorías y convertirlas en una Serie
all_categories_series = all_categories_series.str.split(',').explode().str.strip()

# Contar la frecuencia de cada categoría
category_counts = all_categories_series.value_counts()

# Obtener el top 5 de categorías más comunes
top_10_categories = category_counts.head(10)

# Imprimir el resultado
print("Top 10 categorías más comunes:")
print(top_10_categories)
# Out:
# Top 10 categorías más comunes:
# Restaurants             11881
# Restaurant               9746
# Food                     3535
# Fast food restaurant     2624
# Takeout Restaurant       2070
# Pizza restaurant         2038
# Nightlife                1938
# Sandwiches               1894
# Bars                     1869
# Sandwich shop            1842
# dtype: int64

# %% [markdown]
# En este caso nos quedamos con las cinco categorías que no son 'obvias': Fast food restaurant, Takeout Restaurant, Pizza restaurant, Nightlife, Sandwiches.

# %% [markdown]
# Queda por ver cuántos de los restaurantes son vegetarianos o veganos, para saber si tenemos suficientes datos.

# %%
# Filtra las filas que contienen 'Vegetarian' o 'Vegan' en la columna 'category'
vegetarian_google = metadata_sitios[metadata_sitios['category'].str.contains('Vegetarian|Vegan', case=False)]

# Imprime el resultado
print(vegetarian_google.shape[0])
# Out:
# 462

# %%
# Filtra las filas que contienen 'Vegetarian' o 'Vegan' en la columna 'categories'
vegetarian_yelp = business_yelp[business_yelp['categories'].str.contains('Vegetarian|Vegan', case=False)]

# Imprime el resultado
print(vegetarian_yelp.shape[0])
# Out:
# 381

# %% [markdown]
# Son datos suficientes para analizar competidores directos en el análisis de mercado. Sin embargo debemos extrar reseñas de nuestro cliente directamente de la API de Google Maps para llevar un control de los KPI.

# %% [markdown]
# Es importante explorar el rango que tiene el número de reseñas, esto con la finalidad de descartar posibles outlier. Como se verá a continuación el restaurante con más reseñas tiene 7671 lo cual es totalmente posible.

# %%
# Encuentra el valor máximo y mínimo de 'num_of_reviews'
valor_maximo = metadata_sitios['num_of_reviews'].max()
valor_minimo = metadata_sitios['num_of_reviews'].min()

print(f'El mayor número de reseñas en google es: {valor_maximo}')
print(f'El menor número de reseñas en google es: {valor_minimo}')
# Out:
# El mayor número de reseñas en google es: 7671
# El menor número de reseñas en google es: 1

# %%
# Encuentra el valor máximo y mínimo de 'num_of_reviews'
valor_maximo = business_yelp['num_of_reviews'].max()
valor_minimo = business_yelp['num_of_reviews'].min()

print(f'El mayor número de reseñas en yelp es: {valor_maximo}')
print(f'El menor número de reseñas en yelp es: {valor_minimo}')
# Out:
# El mayor número de reseñas en yelp es: 7400
# El menor número de reseñas en yelp es: 5

# %% [markdown]
# # ANÁLISIS GRÁFICO
#
# Ahora vamos a tratar de visualizar tendencias y a interpretar gráficos, empezamos con dos histogramas que nos representan el progreso temporal que tuvieron las reseñas a través de los años en cada plataforma.

# %%
#Creo una lista de los años en los que se hacen reseñas
all_years=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]

# %%
# Histograma para Google
plt.figure(figsize=(12, 6))
plt.hist(reviews_google['year'], bins=all_years, color='blue', alpha=0.7, label='Google',width=0.6, align='mid')
plt.xlabel('Año')
plt.xticks(np.arange(min(all_years), max(all_years) + 1, 1),fontsize=10)
plt.ylabel('Frecuencia')
plt.title('Histograma de cantidad de Reviews - Google')
plt.legend()
plt.show()

# %%
# Histograma para Yelp
plt.figure(figsize=(12, 6))
plt.hist(reviews_yelp['year'], bins=all_years, color='red', alpha=0.7, label='Yelp',width=0.6, align='mid')
plt.xlabel('Año')
plt.xticks(np.arange(min(all_years), max(all_years) + 1, 1),fontsize=10)
plt.ylabel('Frecuencia')
plt.title('Histograma de cantidad de Reviews - Yelp')
plt.legend()
plt.show()

# %% [markdown]
# Como se puede observar hay un fuerte crecimiento en las reseñas, entre los años 2015 y 2019; desde el 2020 hay una tendencia a la baja debido a la pandemia y las consecuencias de la cuarentena preventiva.

# %%
# Elimino los espacios laterales de las cadenas de texto en la columna 'city'
business_yelp['city'] = business_yelp['city'].str.strip()

metadata_sitios['city'] = metadata_sitios['city'].str.strip()

# %% [markdown]
# Como dije anteriormente, es mejor enfocarnos en las tres ciudades con mayor número de restaurante, ya que esto indica una economía dinámica y zonas comerciales atractivas. Esto ya entra en una etapa de 'pre-análisis de mercado', donde veremos que con los datos que tenemos podemos detectar patrones interesantes.
#
# A continuación se realizarán mapas de calor de la presencia de restaurantes en las tres ciudades elegidas: Miami, Tampa y Las Vegas.

# %%
#Muestro cuantos restaurantes de Miami hay en el Dataset business_yelp

business_yelp[business_yelp['city']=='Miami'].head(5)
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, num_of_reviews, categories]
# Index: []

# %%
#Muestro cuantos restaurantes de Miami hay en el Dataset metadata_sitios

metadata_sitios[metadata_sitios['city']=='Miami'].head(5)
# Out:
#                                               address  avg_rating  \
# 12                     Choices Cafe,  711 NW 27th Ave         4.6
# 18   Biscayne Backyard Barbecue,  11064 Biscayne Blvd         3.9
# 21  Crab Du Jour Cajun Seafood & Bar,  3201 N Miam...         4.7
# 28  Pizza cubana& Italiana Dileo's House LLC,  730...         4.9
# 67                  Palma Juice Co.,  8300 NE 2nd Ave         4.4
#
#                                              category  \
# 12                                         Restaurant
# 18                                         Restaurant
# 21  Seafood restaurant, Bar, Cajun restaurant, Chi...
# 28                                   Pizza restaurant
# 67                 Juice shop, Health food restaurant
#
#                                   gmap_id   latitude  longitude  \
# 12  0x88d9b719170a9f61:0x30d454a980f76ad3  25.779837 -80.239103
# 18  0x88d9b395c6179c89:0x914b0aafb453b3b5  25.877904 -80.168434
# 21  0x88d9b1f38dff4dff:0x61443de98cd9c88c  25.807920 -80.194382
# 28  0x88d9b714af842939:0xbc6dc5c9cb27536e  25.769772 -80.313921
# 67  0x88d9b1005bc3752d:0xb173e4bc55c800f1  25.851944 -80.193245
#
#                                         name  num_of_reviews  \
# 12                              Choices Cafe              45
# 18                Biscayne Backyard Barbecue              23
# 21          Crab Du Jour Cajun Seafood & Bar              88
# 28  Pizza cubana& Italiana Dileo's House LLC              38
# 67                           Palma Juice Co.               8
#
#                                      relative_results state   city
# 12  [0x88d9b486489d7f3f:0x3e02d9f17e126101, 0x88d9...    FL  Miami
# 18                                               None    FL  Miami
# 21                                               None    FL  Miami
# 28  [0x88d9b846a5d55897:0xfc623bf8c2e20ca7, 0x88d9...    FL  Miami
# 67  [0x88d9b3d4f27cb327:0xd92533e82b8b689, 0x88d9b...    FL  Miami

# %%
#Creo un dataframe para Miami

Miami_sitios=metadata_sitios[metadata_sitios['city']=='Miami']

# %%
# Crea un mapa interactivo centrado en Miami con la librería folium
miami_map = folium.Map(location=[25.7617, -80.1918], zoom_start=11, control_scale=True)

# Crea un mapa de calor y lo agrega al mapa de Miami
heat_data = [[point.latitude, point.longitude] for point in Miami_sitios.itertuples()]
HeatMap(heat_data).add_to(miami_map)

#Visualiza el mapa
miami_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60bcfbda667e9a626a04f14c79f25dfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60bcfbda667e9a626a04f14c79f25dfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60bcfbda667e9a626a04f14c79f25dfa = L.map(
#                 &quot;map_60bcfbda667e9a626a04f14c79f25dfa&quot;,
#                 {
#                     center: [25.7617, -80.1918],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_60bcfbda667e9a626a04f14c79f25dfa);
#
#
#
#
#
#             var tile_layer_bffe4f01e66b9f8215de379e4e2ea9d8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_60bcfbda667e9a626a04f14c79f25dfa);
#
#
#             var heat_map_34c940486f8f7771b9f128908bf99d51 = L.heatLayer(
#                 [[25.7798366, -80.23910339999999], [25.8779042, -80.1684336], [25.80792, -80.1943823], [25.769771799999997, -80.31392129999999], [25.851944099999997, -80.1932454], [25.7326205, -80.3707], [25.7871651, -80.21294379999999], [25.798617699999998, -80.1994059], [25.876777099999998, -80.2104813], [25.761476, -80.325898], [25.7798366, -80.23910339999999], [25.8779042, -80.1684336], [25.80792, -80.1943823], [25.769771799999997, -80.31392129999999], [25.851944099999997, -80.1932454], [25.7326205, -80.3707], [25.7871651, -80.21294379999999], [25.798617699999998, -80.1994059], [25.876777099999998, -80.2104813], [25.761476, -80.325898], [25.832614099999997, -80.19002189999999], [25.5989008, -80.35443959999999], [25.732790299999998, -80.3356063], [25.760706499999998, -80.1952979], [25.8397641, -80.184463], [25.796297799999998, -80.3197521], [25.818437799999998, -80.31308469999999], [25.720113299999998, -80.2763875], [25.7676664, -80.1895552], [25.746303299999997, -80.2219976], [25.831798, -80.214912], [25.760705599999998, -80.1914888], [25.704978999999998, -80.285302], [25.7998805, -80.2011916], [25.759833099999998, -80.4202289], [25.733689, -80.3044879], [25.745692, -80.39014], [25.8103485, -80.31559349999999], [25.759546999999998, -80.4190467], [25.6861905, -80.34216459999999], [25.7740419, -80.194043], [25.7981363, -80.2066778], [25.729039999999998, -80.232987], [25.8075045, -80.19333309999999], [25.8096274, -80.2291755], [25.760469099999998, -80.4212864], [25.7925328, -80.1902745], [25.798593099999998, -80.20343729999999], [25.5964355, -80.3694458], [25.6485482, -80.39962469999999], [25.6983905, -80.4447467], [25.690544, -80.314964], [25.798781599999998, -80.261611], [25.770179, -80.331037], [25.727453, -80.24264699999999], [25.7301236, -80.4024295], [25.7500163, -80.2418323], [25.802250299999997, -80.2319551], [25.762428, -80.1933188], [25.802936, -80.19153299999999], [25.802139999999998, -80.19265], [25.7332015, -80.33924569999999], [25.8131579, -80.19511589999999], [25.749798199999997, -80.2494488], [25.728565399999997, -80.2424307], [25.7275952, -80.2409972], [25.7328528, -80.3311611], [25.760889799999998, -80.19477359999999], [25.7735721, -80.1970523], [25.671944399999997, -80.3713106], [25.7301236, -80.4024295], [25.7675993, -80.37453339999999], [25.6581357, -80.43088], [25.7360351, -80.3207982], [25.8136671, -80.19265], [25.8008854, -80.2001816], [25.754803499999998, -80.2304261], [25.657633, -80.43101829999999], [25.7742582, -80.19383859999999], [25.6618838, -80.39362679999999], [25.7680212, -80.3762636], [25.7942809, -80.24758969999999], [25.702202699999997, -80.36989969999999], [25.729433399999998, -80.4281804], [25.941816199999998, -80.2135672], [25.7951348, -80.2295432], [25.778254, -80.2146061], [25.7337353, -80.37916299999999], [25.7952332, -80.1887983], [25.788195899999998, -80.19305419999999], [25.8830363, -80.2377078], [25.827415799999997, -80.2003506], [25.788390999999997, -80.1894475], [25.767835599999998, -80.1962315], [25.7619527, -80.1914567], [25.791843, -80.318055], [25.783561, -80.34720999999999], [25.7139618, -80.4295851], [25.8092905, -80.2254979], [25.777707, -80.3706916], [25.779690199999997, -80.24229629999999], [25.7545112, -80.23863539999999], [25.7610063, -80.1949526], [25.814406299999998, -80.1920834], [25.6878288, -80.312731], [25.8123337, -80.1917201], [25.767495399999998, -80.1891038], [25.7962882, -80.2234682], [25.7736187, -80.2066188], [25.779485899999997, -80.2339922], [25.7821082, -80.1902764], [25.8038469, -80.1939712], [25.7642845, -80.1935585], [25.7638248, -80.1933181], [25.796242499999998, -80.3198609], [25.5901832, -80.3618827], [25.7703794, -80.2144359], [25.7277584, -80.2454521], [25.758689, -80.19142959999999], [25.748584599999997, -80.3771941], [25.8122458, -80.19

# %% [markdown]
# Aquí se puede ver que nuestros datos son bastante coherentes, la zona más caliente es la que está más cerca de Miami Beach y las zonas más turísticas.

# %% [markdown]
# Repetimos el proceso para Tampa y para Las Vegas.

# %%
business_yelp[business_yelp['city']=='Tampa'].head(5)
# Out:
#                business_id                           name  \
# 9   QjV4v7q_pt7tt3K1US7IHg             PDQ Temple Terrace
# 27  sUQ-OfJYSNfz-cimEjoaXQ                Soho Oasis Cafe
# 28  z9wCTHYI2VZy9YIblwSsgg  The Silo Eatery Coffee Bakery
# 35  dIpTuL2T1L98GQGU17IeSw                     The Bricks
# 37  FW1PXpUq-yOs-5O_gqz3AQ                 Big Mike's BBQ
#
#                        address   city state postal_code   latitude  longitude  \
# 9            5112 E Fowler Ave  Tampa    FL       33617  28.054888 -82.399548
# 27            410 S Howard Ave  Tampa    FL       33606  27.940206 -82.482884
# 28  9036 Brittany Way, Bldg 18  Tampa    FL       33619  27.946496 -82.355563
# 35              1327 E 7th Ave  Tampa    NV       33605  27.960024 -82.444401
# 37             6901 Sheldon Rd  Tampa    NV       33615  28.011500 -82.582840
#
#     stars  num_of_reviews                                         categories
# 9     3.0               5   Fast Food, Sandwiches, Chicken Shop, Restaurants
# 27    3.5               7                        Restaurants, Middle Eastern
# 28    4.0               5   Coffee & Tea, Restaurants, Food, Cafes, Bakeries
# 35    4.0             548  Bars, Breakfast & Brunch, Restaurants, America...
# 37    4.5              32                              Restaurants, Barbeque

# %%
metadata_sitios[metadata_sitios['city']=='Tampa'].head(5)
# Out:
#                                               address  avg_rating  \
# 23               Flock and Stock,  615 Channelside Dr         2.8
# 116              Flock and Stock,  615 Channelside Dr         2.8
# 288  D'Alessio Pizza & Pastries,  14831 N Florida Ave         5.0
# 290              Lenny's Sub Shop,  5701 W Waters Ave         1.0
# 291             Bennigan's,  615 Channelside Dr #5942         2.0
#
#                                               category  \
# 23                                          Restaurant
# 116                                         Restaurant
# 288                                         Restaurant
# 290  American restaurant, Box lunch supplier, Cater...
# 291                                         Restaurant
#
#                                    gmap_id   latitude  longitude  \
# 23   0x88c2c5c515fa6e53:0xee4f630ca314fe01  27.943383 -82.447510
# 116  0x88c2c5c515fa6e53:0xee4f630ca314fe01  27.943383 -82.447510
# 288  0x88c2c75b830ec3fb:0x7ef881d17cd34808  28.083660 -82.459118
# 290  0x88c2c1ea8f4404f9:0xc7ebf2a550f8869d  28.026061 -82.542637
# 291  0x88c2c4f199418f8f:0x610540c2747e67a6  27.943199 -82.446677
#
#                            name  num_of_reviews  \
# 23              Flock and Stock              52
# 116             Flock and Stock              52
# 288  D'Alessio Pizza & Pastries               3
# 290            Lenny's Sub Shop               1
# 291                  Bennigan's               1
#
#                                       relative_results state   city
# 23             [0x88c2c5056de83ac1:0x620ac50153c61f98]    FL  Tampa
# 116            [0x88c2c5056de83ac1:0x620ac50153c61f98]    FL  Tampa
# 288  [0x88c2c37668665b27:0x3c52ed3ffa3a1fc4, 0x88c2...    FL  Tampa
# 290                                               None    FL  Tampa
# 291  [0x88c2c346304dafd9:0xb0764bb9394a6267, 0x88c2...    FL  Tampa

# %%
metadata_sitios_tampa=metadata_sitios[metadata_sitios['city']=='Tampa'][['longitude','latitude']]
business_yelp_tampa=business_yelp[business_yelp['city']=='Tampa'][['longitude','latitude']]

Tampa_sitios = pd.concat([metadata_sitios_tampa, business_yelp_tampa], ignore_index=True).drop_duplicates()

# %%
# Crea un mapa centrado en Tampa
tampa_map = folium.Map(location=[27.9506, -82.4572], zoom_start=11)  # Coordenadas aproximadas del centro de Tampa

# Crea un mapa de calor
heat_data = Tampa_sitios[['latitude', 'longitude']].values.tolist()
HeatMap(heat_data).add_to(tampa_map)

tampa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a4bbb98da2bc7304519d9ebcfb428b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a4bbb98da2bc7304519d9ebcfb428b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a4bbb98da2bc7304519d9ebcfb428b4 = L.map(
#                 &quot;map_7a4bbb98da2bc7304519d9ebcfb428b4&quot;,
#                 {
#                     center: [27.9506, -82.4572],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cafcce7b5f4864a58cfc630589a6f6fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a4bbb98da2bc7304519d9ebcfb428b4);
#
#
#             var heat_map_810309f8f1d6d47093ce23721a8651ec = L.heatLayer(
#                 [[27.943382999999997, -82.44751], [28.083660499999997, -82.45911799999999], [28.0260614, -82.5426367], [27.9431993, -82.4466767], [27.9966667, -82.52749999999999], [27.942795, -82.434951], [27.8794164, -82.5062741], [27.9965004, -82.4302496], [28.0024017, -82.5946378], [27.922487, -82.371517], [28.0252013, -82.5356121], [28.0247456, -82.50348749999999], [28.027875899999998, -82.4851226], [27.8798076, -82.49363319999999], [28.131250299999998, -82.3639298], [27.9821848, -82.56476889999999], [28.025548399999998, -82.45825169999999], [28.061134799999998, -82.54330399999999], [27.92683, -82.453823], [28.0328083, -82.41170559999999], [27.956996699999998, -82.5062935], [28.139198, -82.3581], [27.9600749, -82.4372231], [28.028283899999998, -82.5488287], [27.9390511, -82.5070432], [28.0113493, -82.6101912], [27.941876299999997, -82.369613], [27.9417291, -82.4822499], [27.9407937, -82.4832849], [28.088737799999997, -82.4052239], [28.1553799, -82.3566536], [27.946331299999997, -82.47641469999999], [28.068723799999997, -82.4412916], [28.0582182, -82.4341707], [27.953401099999997, -82.37764], [27.9416823, -82.4785967], [27.950975399999997, -82.4597047], [28.025194499999998, -82.5149835], [27.941899499999998, -82.3703762], [27.9773329, -82.44275669999999], [28.004082999999998, -82.504682], [27.9626278, -82.5694048], [27.959294399999997, -82.4976028], [28.0785152, -82.50797179999999], [28.0209045, -82.4837486], [27.8998335, -82.3691327], [27.98094, -82.3595943], [28.0720103, -82.4292703], [27.9518381, -82.4847702], [28.169016, -82.356628], [27.959073999999998, -82.4829864], [27.950156, -82.46019799999999], [27.949119999999997, -82.458252], [28.027281199999997, -82.3927831], [27.9430116, -82.4474659], [27.9928256, -82.3717325], [28.0663584, -82.5031973], [27.966465499999998, -82.4846128], [27.9374988, -82.4801162], [27.948456399999998, -82.4728466], [28.0639851, -82.5028018], [27.9432148, -82.3495137], [28.0265907, -82.51558179999999], [28.047403, -82.5169421], [28.0699601, -82.4751699], [27.942026199999997, -82.479062], [27.9821639, -82.5647165], [27.9452568, -82.5258343], [27.9600843, -82.4384412], [28.042586699999998, -82.5040049], [27.9572385, -82.5023248], [28.1434224, -82.2910832], [28.012913599999997, -82.5827869], [27.9603762, -82.4103611], [27.9938282, -82.3942951], [28.068742999999998, -82.441405], [27.9526446, -82.45933939999999], [27.9475694, -82.4552069], [27.9685921, -82.4850696], [27.9992725, -82.5631532], [28.069731599999997, -82.576807], [27.9709476, -82.5688593], [28.0783933, -82.506146], [28.0695646, -82.4301266], [28.0577911, -82.42399209999999], [27.9569777, -82.4805063], [28.032095299999998, -82.3986956], [27.9671469, -82.3791675], [27.982421799999997, -82.53177889999999], [27.9581356, -82.5236797], [28.030758, -82.644618], [27.948148699999997, -82.4568449], [28.01024, -82.402247], [28.008611, -82.3942469], [28.032113799999998, -82.4320061], [28.0286692, -82.5057506], [27.935366, -82.4832318], [28.056767299999997, -82.5821536], [27.9459344, -82.5052106], [27.9014895, -82.5059127], [27.9274022, -82.5125537], [28.026092499999997, -82.5577994], [27.9587853, -82.48274239999999], [28.0640504, -82.50441789999999], [28.1445959, -82.2819588], [28.0250231, -82.5038141], [28.0098772, -82.4596598], [28.029205599999997, -82.6387288], [28.146015, -82.354809], [28.057125, -82.5821378], [27.9629253, -82.5060063], [28.015754299999998, -82.50531989999999], [28.067101899999997, -82.3969437], [27.990653599999998, -82.4349969], [27.9611064, -82.4640636], [27.9833301, -82.5495967], [27.9445323, -82.5107628], [28.044113499999998, -82.5973807], [28.0250508, -82.46501479999999], [28.0568901, -82.5051838], [28.146242299999997, -82.3545548], [27.9958405, -82.4211888], [27.945656999999997, -82.456744], [27.9599852, -82.4023436], [27.9577021, -82.5333893], [27.8803475, -82.4941946], [28.0556718, -82.4

# %%
business_yelp[business_yelp['city']=='Las Vegas']
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, num_of_reviews, categories]
# Index: []

# %%
metadata_sitios[metadata_sitios['city']=='Las Vegas'].head(5)
# Out:
#                                               address  avg_rating  \
# 16  El Yaqui Mexican Food & Desserts,  5120 W Char...         4.9
# 30  El chiringuito mexican snacks.,  4907 Vegas Dr...         4.8
# 35       Geyland Claypot Rice,  3000 S Las Vegas Blvd         1.8
# 58             Domino's Pizza,  6540 E Lake Mead Blvd         3.7
# 61  Carmines Little Italy Instant,  5570 W Flaming...         5.0
#
#                                              category  \
# 16                                         Restaurant
# 30                                         Restaurant
# 35                             Singaporean restaurant
# 58  Pizza delivery, Delivery Restaurant, Takeout R...
# 61                                 Italian restaurant
#
#                                   gmap_id   latitude   longitude  \
# 16  0x80c8c10f727e3ae1:0x9085c8978a7b1813  36.159371 -115.211149
# 30  0x80c8c1186114520b:0x181d6e75c4cd85ed  36.187988 -115.207601
# 35  0x80c8c546ee1c5d7d:0xd99073e590b4dea7  36.134783 -115.165538
# 58  0x80c8dd7678249c49:0x6f2556114030dded  36.196051 -115.030257
# 61  0x80c8c6c19d4096eb:0x49c4f8ca0fdfd052  36.115355 -115.217713
#
#                                 name  num_of_reviews  \
# 16  El Yaqui Mexican Food & Desserts              15
# 30    El chiringuito mexican snacks.              18
# 35              Geyland Claypot Rice               5
# 58                    Domino's Pizza               8
# 61     Carmines Little Italy Instant               1
#
#                                      relative_results state       city
# 16                                               None    NV  Las Vegas
# 30                                               None    NV  Las Vegas
# 35                                               None    NV  Las Vegas
# 58                                               None    NV  Las Vegas
# 61  [0x80c8c15614e1be9b:0x5ce10cb0928d4b96, 0x80c8...    NV  Las Vegas

# %%
Vegas_sitios=metadata_sitios[metadata_sitios['city']=='Las Vegas']

# %%
# Crea un mapa centrado en Las Vegas
vegas_map = folium.Map(location=[36.1699, -115.1398], zoom_start=11)  # Coordenadas aproximadas del centro de Las Vegas

# Crea un mapa de calor
heat_data_vegas = Vegas_sitios[['latitude', 'longitude']].values.tolist()
HeatMap(heat_data_vegas).add_to(vegas_map)

vegas_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72eb4fd2b8f9b4f67a724827bec1e54f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72eb4fd2b8f9b4f67a724827bec1e54f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72eb4fd2b8f9b4f67a724827bec1e54f = L.map(
#                 &quot;map_72eb4fd2b8f9b4f67a724827bec1e54f&quot;,
#                 {
#                     center: [36.1699, -115.1398],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a704a5e02648035137123fad5d0d8d3b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72eb4fd2b8f9b4f67a724827bec1e54f);
#
#
#             var heat_map_54f14eadcc0ba06983fcf9348a4ed12f = L.heatLayer(
#                 [[36.159371199999995, -115.21114879999999], [36.1879884, -115.2076015], [36.134782699999995, -115.1655377], [36.1960508, -115.0302571], [36.1153547, -115.21771349999999], [36.099651, -115.2431062], [36.03172, -115.24430419999999], [36.0846722, -115.29419809999999], [36.159371199999995, -115.21114879999999], [36.1879884, -115.2076015], [36.134782699999995, -115.1655377], [36.1960508, -115.0302571], [36.1153547, -115.21771349999999], [36.099651, -115.2431062], [36.03172, -115.24430419999999], [36.0846722, -115.29419809999999], [36.159489, -115.17198049999999], [36.1800409, -115.18057879999999], [36.0627912, -115.2414812], [36.1092969, -115.15410209999999], [36.167778299999995, -115.0636486], [36.1254955, -115.1969622], [36.1206111, -115.1768386], [36.100395299999995, -115.31426289999999], [36.1272875, -115.1448281], [36.2020465, -115.24176659999999], [36.143505499999996, -115.2206423], [36.1585287, -115.29088899999999], [36.1596137, -115.22045609999999], [36.15959, -115.2424879], [36.133052, -115.0849016], [36.1165009, -115.10437859999999], [36.0996956, -115.11775469999999], [36.1326, -115.1764647], [36.0530068, -115.27971699999999], [36.213666499999995, -115.31870889999999], [36.276843, -115.20975779999999], [36.1216982, -115.16970669999999], [36.1662749, -115.14447919999999], [36.2208398, -115.0776927], [36.0838938, -115.1537166], [36.0558317, -115.12005359999999], [36.3036994, -115.67961319999999], [36.1413815, -115.1699404], [36.1441284, -115.1602418], [36.0101398, -115.13577719999999], [36.1738413, -115.08136839999999], [36.109532, -115.1538155], [36.140679, -115.1424227], [36.166821999999996, -115.13430369999999], [36.120813, -115.150154], [36.123311099999995, -115.2075031], [36.076823499999996, -115.1015041], [36.129819, -115.27457749999999], [36.1269658, -115.2412518], [36.1078246, -115.1745179], [36.1750829, -115.2920875], [36.116335299999996, -115.1714355], [36.1352668, -115.15062119999999], [36.1627923, -115.1513217], [36.080447, -115.1465302], [36.1344153, -115.1646359], [36.2500007, -115.24431279999999], [36.1250301, -115.1356491], [36.099556799999995, -115.10595169999999], [36.0979917, -115.2977607], [36.1121161, -115.2793597], [36.0978091, -115.2976626], [36.1139745, -115.3056038], [36.1347039, -115.16536169999999], [36.0553391, -115.2259983], [36.0987307, -115.175777], [36.2384178, -115.23201429999999], [36.0164931, -115.11706889999999], [36.1586808, -115.2367199], [36.0101659, -115.13516039999999], [36.1362611, -115.1512539], [36.113141, -115.06201899999999], [36.1652383, -115.1612208], [36.1177632, -115.171139], [36.0430345, -115.1514327], [36.1944857, -115.2069942], [36.0366779, -115.24264079999999], [36.0065454, -115.2064695], [36.0782108, -115.24333349999999], [36.116782, -115.2062658], [36.1304916, -115.1960362], [36.202203399999995, -115.24184969999999], [36.218888, -115.2082758], [36.158707, -115.236735], [36.129542199999996, -115.10880089999999], [36.103041499999996, -115.1683193], [36.1153942, -115.2805173], [36.125325, -115.19583329999999], [36.1586808, -115.2367199], [36.125940799999995, -115.1352186], [36.158706699999996, -115.23673529999999], [36.0527015, -115.2424989], [36.1130741, -115.1199437], [36.1265271, -115.2194373], [36.1146078, -115.20679369999999], [36.019067899999996, -115.2616662], [36.005795, -115.243195], [36.1268209, -115.24207419999999], [36.159607, -115.22207999999999], [36.1371335, -115.1645466], [36.1813968, -115.1393849], [36.1190372, -115.17600499999999], [36.1133555, -115.3095063], [36.122549, -115.169417], [36.1264792, -115.2122275], [36.0852685, -115.1541263], [36.084613999999995, -115.2409581], [36.191469999999995, -115.25932999999999], [36.0979658, -115.2978253], [36.066950999999996, -115.25123459999999], [36.166963599999995, -115.2588449], [36.1482429, -115.1612014], [36.121502299999996, -115.1443755], [36.2898612, -115.285

# %% [markdown]
# Por último queda ver si tenemos información suficiente para enfocarnos en nuestro nicho referente a la gastronomía vegetariana y/o vegana. Ya vimos que si tenemos una gran cantidad de restaurante, queda por ver las reseñas, para esto decidimos hacer dos histogramas parecidos a los que se hicieron anteriormente pero enfocándonos únicamente en restaurantes de la especialidad.

# %%
#Crea listas de id de negocios vegetarianos en las dos plataformas
lista_vegetarianos_google=vegetarian_google['gmap_id'].tolist()
lista_vegetarianos_yelp=vegetarian_yelp['business_id'].tolist()

# %%
#Filtra las reviews que pertenecen a alguno de los restaurantes enlistados
reviews_vegetarianas_google = reviews_google[reviews_google['gmap_id'].isin(lista_vegetarianos_google)]
reviews_vegetarianas_yelp = reviews_yelp[reviews_yelp['business_id'].isin(lista_vegetarianos_yelp)]

# %%
# Histograma para restaurantes vegetarianos en Google Maps
plt.figure(figsize=(12, 6))
plt.hist(reviews_vegetarianas_google['year'], bins=all_years, color='green', alpha=0.7, label='Google',width=0.6, align='mid')
plt.xlabel('Año')
plt.xticks(np.arange(min(all_years), max(all_years) + 1, 1),fontsize=10)
plt.ylabel('Frecuencia')
plt.title('Histograma de cantidad de Reviews Vegetarianas - Google')
plt.legend()
plt.show()

# %%
# Histograma para restaurantes vegetarianos en Yelp
plt.figure(figsize=(12, 6))
plt.hist(reviews_vegetarianas_yelp['year'], bins=all_years, color='green', alpha=0.4, label='Yelp',width=0.6, align='mid')
plt.xlabel('Año')
plt.xticks(np.arange(min(all_years), max(all_years) + 1, 1),fontsize=10)
plt.ylabel('Frecuencia')
plt.title('Histograma de cantidad de Reviews Vegetarianas - Yelp')
plt.legend()
plt.show()

# %% [markdown]
# Se aprecian tendencias similares a las de los restaurantes en general, esto indica que el consumo de la comida vegetariana incrementa y representa un gran nicho para invertir.

# %% [markdown]
# Los tips nos serán de utilidad para aprender de los errores de otros restaurantes y realizar estrategias más efectivas. Para esto debemos encontrar los tips que se hacen a los restaurantes vegetarianos o veganos y tener conocimiento de cuántos tenemos para un futuro análisis.

# %%
tips_vegetarianos = tips_yelp[tips_yelp['business_id'].isin(lista_vegetarianos_yelp)]

# %%
print(f"El número de tips a restaurantes vegetarianos es: {tips_vegetarianos.shape[0]}")
# Out:
# El número de tips a restaurantes vegetarianos es: 7154
